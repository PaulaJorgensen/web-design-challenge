# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file = "cities.csv"

# Read Purchasing File and store into Pandas data frame
data = pd.read_csv(file)

data
# Out:
#      Unnamed: 0            city   temp  max temp  humidity  cloudiness  \
# 0             0       hithadhoo  83.23     83.23        80          94
# 1             1      nanortalik  29.50     29.50        85         100
# 2             2      bredasdorp  60.80     60.80        87          96
# 3             3         tsabong  63.73     63.73        91         100
# 4             4         isangel  86.00     86.00        70          75
# 5             5       jamestown  73.67     73.67        27           0
# 6             6         mataura  63.14     63.14        48          50
# 7             7           raton  41.40     44.60        69           1
# 8             8           kapaa  79.81     80.60        74          40
# 9             9           avera  52.50     55.00        87          90
# 10           10       eskisehir  18.50     19.40        92           0
# 11           11         caxambu  65.07     65.07        96          83
# ...

# %%
data_df = pd.DataFrame({'City ID':data['Unnamed: 0'], 'City':data['city'], 'Temp': data['temp'], 'Max Temp': data['max temp'],
                       'Humidity':data['humidity'], 'Cloudiness':data['cloudiness'], 'Wind Speed':data['wind speed'],
                        'LAT':data['lat'], 'LON':data['lon'], 'City Country':data['city country'], "City Datetime":data['city datetime']})
data_df.head()
# Out:
#    City ID        City   Temp  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        0   hithadhoo  83.23     83.23        80          94       17.09
# 1        1  nanortalik  29.50     29.50        85         100        7.36
# 2        2  bredasdorp  60.80     60.80        87          96        5.99
# 3        3     tsabong  63.73     63.73        91         100       11.41
# 4        4     isangel  86.00     86.00        70          75        9.17
#
#      LAT     LON City Country  City Datetime
# 0  -0.60   73.08           MV     1575677661
# 1  60.14  -45.24           GL     1575677659
# 2 -34.53   20.04           ZA     1575677516
# 3 -26.02   22.40           BW     1575677782
# 4 -19.55  169.27           VU     1575677783

# %%
#render dataframe as html
html = data_df.to_html()

# %%
#write html to file
text_file = open("Assets/Data1.html", "w")
text_file.write(html)
text_file.close()
